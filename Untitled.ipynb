# %%
import requests
import pandas as pd
from serpapi import GoogleScholarSearch
import re
import random
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from IPython.display import display
import pickle
from pyvis.network import Network
import json

# SerpAPI key can be set globally or per search
GoogleScholarSearch.SERP_API_KEY = "ce9dffa0dfa0822e54e9008226d1dbbe92165f4ae7096b2c46734945c466fba5"


def Punto1():
    # 1. A partire da nodes.csv, utilizzare la libreria Python SerpAPI per scaricare, per
    # ciascuno dei 7 autori elencati:
    # - author_id: ID identificativo del profilo Google Scholar
    # - cited_by: numero totale di citazioni ricevute
    # - interests: elenco degli interessi di ciascun autore
    # Sfruttando la libreria Python Pandas, usare la struttura dati DataFrame per
    # aggiornare il file originale con apposite colonne e memorizzarlo nella cartella /data.

    # Leggo file csv e carico dataframe
    df_nodes = pd.read_csv("data/nodes.csv")
    # display(df_nodes)
    df_nodes_aux = pd.DataFrame(columns=["author_id", "cited_by", "interests"])

    # itero per la coppia name e affilations
    for name, affilations in zip(df_nodes["name"], df_nodes["affiliations"]):

        # Ricerco name tra i profili presenti su Google Scholar
        params = {
            "engine": "google_scholar_profiles",
            "hl": "en",
            "mauthors": name
            }

        search = GoogleScholarSearch(params)
        results = search.get_dict()["profiles"]

        # So che posso avere più profili possibili, ma cerco affilations
        correct_affilations = None

        for result in results:
            if result["affiliations"] == affilations:
                correct_affilations = result

        # display("correct_affilations: ", correct_affilations)

        # -> Trovato profilo corretto !

        # per ciascuno dei 7 autori elencati:
        # - author_id: ID identificativo del profilo Google Scholar
        # - cited_by: numero totale di citazioni ricevute
        # - interests: elenco degli interessi di ciascun autore

        # Creo DataFrame
        author_id = correct_affilations.get('author_id')
        cited_by = correct_affilations.get('cited_by', 'value')
        interests = correct_affilations.get('interests')
        title = None
        for interest in interests:
            title = interest.get('title', '')

        # print(author_id)
        # print(cited_by)
        # print(title)

        # non funziona append!
        new_row = {'author_id': author_id, 'cited_by': cited_by, 'interests': title}
        df_nodes_aux.loc[len(df_nodes_aux)] = new_row

        # esco dal for

    df = pd.concat([df_nodes, df_nodes_aux], axis=1)
    # display(df)

    # scarico dataframe
    df.to_csv("data/nodes.csv", index=False)

def Punto2():
    # 2. Per ciascuno dei 7 autori, utilizzare il suo ID per accedere al relativo profilo Google
    # Scholar e scaricare l’elenco dei suoi coautori, sempre via SerpAPI. Con tale elenco di nomi:

    df_nodes = pd.read_csv("data/nodes.csv")
    df_coauthor = pd.DataFrame(columns=["name", "affiliations", "author_id", "cited_by", "interests"])

    for author_id in df_nodes["author_id"]:
        #print(author_id)
        params = {
            "engine": "google_scholar_author",
            "hl": "en",
            "author_id": author_id
        }

        search = GoogleScholarSearch(params)
        results_author_id = search.get_dict() # elenco di coautori per ciascun autore

        # a. Utilizzare le SerpAPI per cercare su Google Scholar un ricercatore che
        # corrisponde a tale nome. Per ciascuno, salvare name, affiliations,
        # author_id, cited_by e interests in un nuovo DataFrame contenente tutte
        # queste informazioni relative ai coautori dei 7 autori originari.


        for coauthor in results_author_id["co_authors"]:

            coauthor_name = {coauthor['name']}

            # trova ricercatore che corrisponde a tale nome

            # Ricerco name tra i profili presenti su Google Scholar
            params = {
                "engine": "google_scholar_profiles",
                "hl": "en",
                "mauthors": coauthor_name
            }

            search = GoogleScholarSearch(params)

            # prendo primo profilo
            results_author_id_profile = search.get_dict()["profiles"][0]
            results_author_id_profile1 = results_author_id_profile
            #print(results_author_id_profile1)
            # Per ciascuno, salvare name, affiliations, author_id, cited_by e interests
            # in un nuovo DataFrame contenente tutte queste informazioni relative ai coautori
            # dei 7 autori originari.
            print(results_author_id_profile1)
            # Creo DataFrame
            coauthor_affiliations = results_author_id_profile1.get('affiliations')
            #print(coauthor_affilations)
            coauthor_id = results_author_id_profile1.get('author_id')
            #print(coauthor_id)
            coauthor_cited_by = results_author_id_profile1.get('cited_by', 'value')
            #print(coauthor_cited_by)
            coauthor_interests = results_author_id_profile1.get('interests')
            #print(coauthor_interests)
            coauthor_title = None

            try:
                for interest in coauthor_interests:
                    coauthor_title = interest.get('title', '')
            except:
                coauthor_title = ""

            # non funziona append!
            new_row = {'coauthor_name': coauthor_name, 'coauthor_affiliations': coauthor_affiliations, 'coauthor_author_id': coauthor_id, 'coauthor_cited_by': coauthor_cited_by, 'coauthor_interests': coauthor_title}
            df_coauthor.loc[len(df_coauthor)] = new_row
            print(new_row)
            # esco dal for
    display(df_coauthor)
    # b. Concatenare il DataFrame con i 7 autori originari e quello dei coautori
    # generato al punto 2a in un unico DataFrame.
    # NOTA BENE: è sufficiente effettuare la ricerca dei profili per nome, non
    # accedere al loro profilo tramite id.
    # ASSUNZIONE: in questo caso non potete identificare il profilo corretto tramite
    # il valore di affiliations, quindi assumete che quello corretto sia il primo
    # ritornato nella lista di authors.

    df_coauthor.to_csv("data/coauthor.csv", index=False)
    # salvataggio non neccessario -> eseguito solo per velocizzare il programma


    # c. Creare un terzo DataFrame con le colonne author1, author2 che
    # rappresenta le co-authorship. In tale DataFrame, una riga rappresenta un
    # arco di coauthorship tra due autori.
    # ESEMPIO: David La Barbera, Michael Soprano è una riga del DataFrame
    # creato al punto 2c se Michael Soprano è coautore di David La Barbera. La
    # co-authorship è binaria, non pesata.

    #->df_edges = pd.DataFrame()
    #->df_edges = pd.concat([df_nodes[""], df_coauthor], axis=1)


Punto2()
# Out:
# {'name': 'Kevin Roitero', 'link': 'https://scholar.google.com/citations?hl=en&user=1xd52jMAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=1xd52jMAAAAJ&engine=google_scholar_author&hl=en', 'author_id': '1xd52jMAAAAJ', 'affiliations': 'University of Udine', 'email': 'Verified email at uniud.it', 'cited_by': 688, 'interests': [{'title': 'Artificial Intelligence', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aartificial_intelligence', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:artificial_intelligence'}, {'title': 'Crowdsourcing and Human Computation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing_and_human_computation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing_and_human_computation'}, {'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=1xd52jMAAAAJ&citpid=6'}
# {'coauthor_name': {'Kevin Roitero'}, 'coauthor_affiliations': 'University of Udine', 'coauthor_author_id': '1xd52jMAAAAJ', 'coauthor_cited_by': 688, 'coauthor_interests': 'Information Retrieval'}
# {'name': 'Stefano Mizzaro', 'link': 'https://scholar.google.com/citations?hl=en&user=2wvJC6IAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=2wvJC6IAAAAJ&engine=google_scholar_author&hl=en', 'author_id': '2wvJC6IAAAAJ', 'affiliations': 'Full professor of Computer Science and Information Technology', 'email': 'Verified email at uniud.it', 'cited_by': 4732, 'interests': [{'title': 'Information retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'mobile systems', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amobile_systems', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:mobile_systems'}, {'title': 'scholarly publishing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ascholarly_publishing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:scholarly_publishing'}, {'title': 'crowdsourcing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing'}, {'title': 'misinformation and fake news detection', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amisinformation_and_fake_news_detection', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:misinformation_and_fake_news_detection'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=2wvJC6IAAAAJ&citpid=1'}
# {'coauthor_name': {'Stefano Mizzaro'}, 'coauthor_affiliations': 'Full professor of Computer Science and Information Technology', 'coauthor_author_id': '2wvJC6IAAAAJ', 'coauthor_cited_by': 4732, 'coauthor_interests': 'misinformation and fake news detection'}
# {'name': 'Gianluca Demartini', 'link': 'https://scholar.google.com/citations?hl=en&user=PCAiILsAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=PCAiILsAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'PCAiILsAAAAJ', 'affiliations': 'Associate Professor at the University of Queensland', 'email': 'Verified email at cs.berkeley.edu', 'cited_by': 5339, 'interests': [{'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'Semantic Web', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asemantic_web', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:semantic_web'}, {'title': 'Human Computation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_computation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_computation'}, {'title': 'Crowdsourcing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=PCAiILsAAAAJ&citpid=6'}
# {'coauthor_name': {'Gianluca Demartini'}, 'coauthor_affiliations': 'Associate Professor at the University of Queensland', 'coauthor_author_id': 'PCAiILsAAAAJ', 'coauthor_cited_by': 5339, 'coauthor_interests': 'Crowdsourcing'}
# {'name': 'Damiano Spina', 'link': 'https://scholar.google.com/citations?hl=en&user=sLzYrNYAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=sLzYrNYAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'sLzYrNYAAAAJ', 'affiliations': 'School of Computing Technologies, RMIT University', 'email': 'Verified email at rmit.edu.au', 'cited_by': 2480, 'interests': [{'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'Text Analytics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Atext_analytics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:text_analytics'}, {'title': 'Data Science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adata_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:data_science'}, {'title': 'Evaluation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aevaluation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:evaluation'}, {'title': 'Human-AI Fact-checking', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_ai_fact_checking', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_ai_fact_checking'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=sLzYrNYAAAAJ&citpid=8'}
# {'coauthor_name': {'Damiano Spina'}, 'coauthor_affiliations': 'School of Computing Technologies, RMIT University', 'coauthor_author_id': 'sLzYrNYAAAAJ', 'coauthor_cited_by': 2480, 'coauthor_interests': 'Human-AI Fact-checking'}
# {'name': 'Michael Soprano', 'link': 'https://scholar.google.com/citations?hl=en&user=ocK0qRUAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=ocK0qRUAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'ocK0qRUAAAAJ', 'affiliations': 'Postdoctoral Research Fellow at the University of Udine', 'email': 'Verified email at uniud.it', 'cited_by': 206, 'interests': [{'title': 'Computer Science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acomputer_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:computer_science'}, {'title': 'Crowdsourcing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=ocK0qRUAAAAJ&citpid=2'}
# {'coauthor_name': {'Michael Soprano'}, 'coauthor_affiliations': 'Postdoctoral Research Fellow at the University of Udine', 'coauthor_author_id': 'ocK0qRUAAAAJ', 'coauthor_cited_by': 206, 'coauthor_interests': 'Crowdsourcing'}
# {'name': 'Vincenzo Della Mea', 'link': 'https://scholar.google.com/citations?hl=en&user=BF3B4KAAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=BF3B4KAAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'BF3B4KAAAAAJ', 'affiliations': 'Associate Professor of Medical Informatics, University of Udine', 'email': 'Verified email at uniud.it', 'cited_by': 2878, 'interests': [{'title': 'medical informatics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amedical_informatics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:medical_informatics'}, {'title': 'telemedicine', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Atelemedicine', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:telemedicine'}, {'title': 'digital pathology', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adigital_pathology', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:digital_pathology'}, {'title': 'biomedical classifications and ontologies', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Abiomedical_classifications_and_ontologies', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:biomedical_classifications_and_ontologies'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=BF3B4KAAAAAJ&citpid=7'}
# {'coauthor_name': {'Vincenzo Della Mea'}, 'coauthor_affiliations': 'Associate Professor of Medical Informatics, University of Udine', 'coauthor_author_id': 'BF3B4KAAAAAJ', 'coauthor_cited_by': 2878, 'coauthor_interests': 'biomedical classifications and ontologies'}
# {'name': 'Davide Ceolin', 'link': 'https://scholar.google.com/citations?hl=en&user=y8Jy518AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=y8Jy518AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'y8Jy518AAAAJ', 'affiliations': 'Tenured Researcher, CWI Amsterdam', 'email': 'Verified email at cwi.nl', 'cited_by': 493, 'interests': [{'title': 'Information Quality', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_quality', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_quality'}, {'title': 'Trust', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Atrust', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:trust'}, {'title': 'Semantic Web', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asemantic_web', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:semantic_web'}, {'title': 'Probabilistic Logic', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprobabilistic_logic', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:probabilistic_logic'}, {'title': 'Provenance', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprovenance', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:provenance'}], 'thumbnail': 'https://scholar.google.com/citations/images/avatar_scholar_56.png'}
# {'coauthor_name': {'Davide Ceolin'}, 'coauthor_affiliations': 'Tenured Researcher, CWI Amsterdam', 'coauthor_author_id': 'y8Jy518AAAAJ', 'coauthor_cited_by': 493, 'coauthor_interests': 'Provenance'}
# {'name': 'Tim Draws', 'link': 'https://scholar.google.com/citations?hl=en&user=UTMHOZMAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=UTMHOZMAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'UTMHOZMAAAAJ', 'affiliations': 'OTTO', 'email': 'Verified email at otto.de', 'cited_by': 1196, 'interests': [{'title': 'Human-Computer Interaction', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_computer_interaction', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_computer_interaction'}, {'title': 'Web Search', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aweb_search', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:web_search'}, {'title': 'Research Methods', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aresearch_methods', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:research_methods'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=UTMHOZMAAAAJ&citpid=3'}
# {'coauthor_name': {'Tim Draws'}, 'coauthor_affiliations': 'OTTO', 'coauthor_author_id': 'UTMHOZMAAAAJ', 'coauthor_cited_by': 1196, 'coauthor_interests': 'Research Methods'}
# {'name': 'Joel Mackenzie', 'link': 'https://scholar.google.com/citations?hl=en&user=3jQ1Zh4AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=3jQ1Zh4AAAAJ&engine=google_scholar_author&hl=en', 'author_id': '3jQ1Zh4AAAAJ', 'affiliations': 'The University of Queensland', 'email': 'Verified email at uq.edu.au', 'cited_by': 640, 'interests': [{'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'Web Search', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aweb_search', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:web_search'}, {'title': 'Algorithms', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aalgorithms', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:algorithms'}, {'title': 'Information Systems', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_systems', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_systems'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=3jQ1Zh4AAAAJ&citpid=8'}
# {'coauthor_name': {'Joel Mackenzie'}, 'coauthor_affiliations': 'The University of Queensland', 'coauthor_author_id': '3jQ1Zh4AAAAJ', 'coauthor_cited_by': 640, 'coauthor_interests': 'Information Systems'}
# {'name': 'Kevin Roitero', 'link': 'https://scholar.google.com/citations?hl=en&user=1xd52jMAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=1xd52jMAAAAJ&engine=google_scholar_author&hl=en', 'author_id': '1xd52jMAAAAJ', 'affiliations': 'University of Udine', 'email': 'Verified email at uniud.it', 'cited_by': 688, 'interests': [{'title': 'Artificial Intelligence', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aartificial_intelligence', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:artificial_intelligence'}, {'title': 'Crowdsourcing and Human Computation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing_and_human_computation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing_and_human_computation'}, {'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=1xd52jMAAAAJ&citpid=6'}
# {'coauthor_name': {'Kevin Roitero'}, 'coauthor_affiliations': 'University of Udine', 'coauthor_author_id': '1xd52jMAAAAJ', 'coauthor_cited_by': 688, 'coauthor_interests': 'Information Retrieval'}
# {'name': 'Stefano Mizzaro', 'link': 'https://scholar.google.com/citations?hl=en&user=2wvJC6IAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=2wvJC6IAAAAJ&engine=google_scholar_author&hl=en', 'author_id': '2wvJC6IAAAAJ', 'affiliations': 'Full professor of Computer Science and Information Technology', 'email': 'Verified email at uniud.it', 'cited_by': 4732, 'interests': [{'title': 'Information retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'mobile systems', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amobile_systems', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:mobile_systems'}, {'title': 'scholarly publishing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ascholarly_publishing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:scholarly_publishing'}, {'title': 'crowdsourcing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing'}, {'title': 'misinformation and fake news detection', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amisinformation_and_fake_news_detection', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:misinformation_and_fake_news_detection'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=2wvJC6IAAAAJ&citpid=1'}
# {'coauthor_name': {'Stefano Mizzaro'}, 'coauthor_affiliations': 'Full professor of Computer Science and Information Technology', 'coauthor_author_id': '2wvJC6IAAAAJ', 'coauthor_cited_by': 4732, 'coauthor_interests': 'misinformation and fake news detection'}
# {'name': 'Gianluca Demartini', 'link': 'https://scholar.google.com/citations?hl=en&user=PCAiILsAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=PCAiILsAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'PCAiILsAAAAJ', 'affiliations': 'Associate Professor at the University of Queensland', 'email': 'Verified email at cs.berkeley.edu', 'cited_by': 5339, 'interests': [{'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'Semantic Web', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asemantic_web', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:semantic_web'}, {'title': 'Human Computation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_computation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_computation'}, {'title': 'Crowdsourcing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=PCAiILsAAAAJ&citpid=6'}
# {'coauthor_name': {'Gianluca Demartini'}, 'coauthor_affiliations': 'Associate Professor at the University of Queensland', 'coauthor_author_id': 'PCAiILsAAAAJ', 'coauthor_cited_by': 5339, 'coauthor_interests': 'Crowdsourcing'}
# {'name': 'Damiano Spina', 'link': 'https://scholar.google.com/citations?hl=en&user=sLzYrNYAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=sLzYrNYAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'sLzYrNYAAAAJ', 'affiliations': 'School of Computing Technologies, RMIT University', 'email': 'Verified email at rmit.edu.au', 'cited_by': 2480, 'interests': [{'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'Text Analytics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Atext_analytics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:text_analytics'}, {'title': 'Data Science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adata_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:data_science'}, {'title': 'Evaluation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aevaluation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:evaluation'}, {'title': 'Human-AI Fact-checking', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_ai_fact_checking', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_ai_fact_checking'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=sLzYrNYAAAAJ&citpid=8'}
# {'coauthor_name': {'Damiano Spina'}, 'coauthor_affiliations': 'School of Computing Technologies, RMIT University', 'coauthor_author_id': 'sLzYrNYAAAAJ', 'coauthor_cited_by': 2480, 'coauthor_interests': 'Human-AI Fact-checking'}
# {'name': 'Davide Ceolin', 'link': 'https://scholar.google.com/citations?hl=en&user=y8Jy518AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=y8Jy518AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'y8Jy518AAAAJ', 'affiliations': 'Tenured Researcher, CWI Amsterdam', 'email': 'Verified email at cwi.nl', 'cited_by': 493, 'interests': [{'title': 'Information Quality', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_quality', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_quality'}, {'title': 'Trust', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Atrust', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:trust'}, {'title': 'Semantic Web', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asemantic_web', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:semantic_web'}, {'title': 'Probabilistic Logic', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprobabilistic_logic', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:probabilistic_logic'}, {'title': 'Provenance', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprovenance', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:provenance'}], 'thumbnail': 'https://scholar.google.com/citations/images/avatar_scholar_56.png'}
# {'coauthor_name': {'Davide Ceolin'}, 'coauthor_affiliations': 'Tenured Researcher, CWI Amsterdam', 'coauthor_author_id': 'y8Jy518AAAAJ', 'coauthor_cited_by': 493, 'coauthor_interests': 'Provenance'}
# {'name': 'David La Barbera', 'link': 'https://scholar.google.com/citations?hl=en&user=MvN8wKEAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=MvN8wKEAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'MvN8wKEAAAAJ', 'affiliations': 'Università Degli Studi Di Udine', 'email': 'Verified email at spes.uniud.it', 'cited_by': 138, 'interests': [{'title': 'Computer Science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acomputer_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:computer_science'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=MvN8wKEAAAAJ&citpid=1'}
# {'coauthor_name': {'David La Barbera'}, 'coauthor_affiliations': 'Università Degli Studi Di Udine', 'coauthor_author_id': 'MvN8wKEAAAAJ', 'coauthor_cited_by': 138, 'coauthor_interests': 'Computer Science'}
# {'name': 'Vincenzo Della Mea', 'link': 'https://scholar.google.com/citations?hl=en&user=BF3B4KAAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=BF3B4KAAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'BF3B4KAAAAAJ', 'affiliations': 'Associate Professor of Medical Informatics, University of Udine', 'email': 'Verified email at uniud.it', 'cited_by': 2878, 'interests': [{'title': 'medical informatics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amedical_informatics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:medical_informatics'}, {'title': 'telemedicine', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Atelemedicine', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:telemedicine'}, {'title': 'digital pathology', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adigital_pathology', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:digital_pathology'}, {'title': 'biomedical classifications and ontologies', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Abiomedical_classifications_and_ontologies', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:biomedical_classifications_and_ontologies'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=BF3B4KAAAAAJ&citpid=7'}
# {'coauthor_name': {'Vincenzo Della Mea'}, 'coauthor_affiliations': 'Associate Professor of Medical Informatics, University of Udine', 'coauthor_author_id': 'BF3B4KAAAAAJ', 'coauthor_cited_by': 2878, 'coauthor_interests': 'biomedical classifications and ontologies'}
# {'name': 'Beatrice Portelli', 'link': 'https://scholar.google.com/citations?hl=en&user=HQZd6wsAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=HQZd6wsAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'HQZd6wsAAAAJ', 'affiliations': 'University of Udine', 'email': 'Verified email at spes.uniud.it', 'cited_by': 143, 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=HQZd6wsAAAAJ&citpid=2'}
# {'coauthor_name': {'Beatrice Portelli'}, 'coauthor_affiliations': 'University of Udine', 'coauthor_author_id': 'HQZd6wsAAAAJ', 'coauthor_cited_by': 143, 'coauthor_interests': ''}
# {'name': 'Giuseppe Serra', 'link': 'https://scholar.google.com/citations?hl=en&user=xz1J-xQAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=xz1J-xQAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'xz1J-xQAAAAJ', 'affiliations': 'Associate Professor of Computer Science, University of Udine', 'email': 'Verified email at uniud.it', 'cited_by': 5317, 'interests': [{'title': 'Machine Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amachine_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:machine_learning'}, {'title': 'Artificial Intelligence', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aartificial_intelligence', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:artificial_intelligence'}, {'title': 'Multimedia', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amultimedia', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:multimedia'}, {'title': 'NLP', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Anlp', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:nlp'}, {'title': 'Multimedia Forensics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amultimedia_forensics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:multimedia_forensics'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=xz1J-xQAAAAJ&citpid=3'}
# {'coauthor_name': {'Giuseppe Serra'}, 'coauthor_affiliations': 'Associate Professor of Computer Science, University of Udine', 'coauthor_author_id': 'xz1J-xQAAAAJ', 'coauthor_cited_by': 5317, 'coauthor_interests': 'Multimedia Forensics'}
# {'name': 'Shaoyang Fan', 'link': 'https://scholar.google.com/citations?hl=en&user=uF87D5kAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=uF87D5kAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'uF87D5kAAAAJ', 'affiliations': 'The University of Queensland', 'email': 'Verified email at uq.edu.au', 'cited_by': 79, 'interests': [{'title': 'Crowdsourcing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing'}, {'title': 'Human computation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_computation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_computation'}, {'title': 'Information Retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'Data Mining', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adata_mining', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:data_mining'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=uF87D5kAAAAJ&citpid=1'}
# {'coauthor_name': {'Shaoyang Fan'}, 'coauthor_affiliations': 'The University of Queensland', 'coauthor_author_id': 'uF87D5kAAAAJ', 'coauthor_cited_by': 79, 'coauthor_interests': 'Data Mining'}
# {'name': 'Giuseppe Primiero', 'link': 'https://scholar.google.com/citations?hl=en&user=srKA534AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=srKA534AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'srKA534AAAAJ', 'affiliations': 'Department of Philosophy, University of Milan', 'email': 'Verified email at unimi.it', 'cited_by': 1115, 'interests': [{'title': 'Logic', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Alogic', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:logic'}, {'title': 'Philosophy of Computer Science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aphilosophy_of_computer_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:philosophy_of_computer_science'}], 'thumbnail': 'https://scholar.google.com/citations/images/avatar_scholar_56.png'}
# {'coauthor_name': {'Giuseppe Primiero'}, 'coauthor_affiliations': 'Department of Philosophy, University of Milan', 'coauthor_author_id': 'srKA534AAAAJ', 'coauthor_cited_by': 1115, 'coauthor_interests': 'Philosophy of Computer Science'}
# {'name': 'Jan Wielemaker', 'link': 'https://scholar.google.com/citations?hl=en&user=7J1vJdEAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=7J1vJdEAAAAJ&engine=google_scholar_author&hl=en', 'author_id': '7J1vJdEAAAAJ', 'affiliations': 'Researcher in Computer Science, VU University Amsterdam', 'email': 'Verified email at vu.nl', 'cited_by': 5050, 'interests': [{'title': 'Logic programming', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Alogic_programming', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:logic_programming'}, {'title': 'Semantic web', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asemantic_web', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:semantic_web'}], 'thumbnail': 'https://scholar.google.com/citations/images/avatar_scholar_56.png'}
# {'coauthor_name': {'Jan Wielemaker'}, 'coauthor_affiliations': 'Researcher in Computer Science, VU University Amsterdam', 'coauthor_author_id': '7J1vJdEAAAAJ', 'coauthor_cited_by': 5050, 'coauthor_interests': 'Semantic web'}
# {'name': 'Tim Draws', 'link': 'https://scholar.google.com/citations?hl=en&user=UTMHOZMAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=UTMHOZMAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'UTMHOZMAAAAJ', 'affiliations': 'OTTO', 'email': 'Verified email at otto.de', 'cited_by': 1196, 'interests': [{'title': 'Human-Computer Interaction', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_computer_interaction', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_computer_interaction'}, {'title': 'Web Search', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aweb_search', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:web_search'}, {'title': 'Research Methods', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aresearch_methods', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:research_methods'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=UTMHOZMAAAAJ&citpid=3'}
# {'coauthor_name': {'Tim Draws'}, 'coauthor_affiliations': 'OTTO', 'coauthor_author_id': 'UTMHOZMAAAAJ', 'coauthor_cited_by': 1196, 'coauthor_interests': 'Research Methods'}
# {'name': 'Alessandro Checco', 'link': 'https://scholar.google.com/citations?hl=en&user=crhkrNcAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=crhkrNcAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'crhkrNcAAAAJ', 'affiliations': 'Computer Science Department - University of Rome La Sapienza', 'email': 'Verified email at uniroma1.it', 'cited_by': 896, 'interests': [{'title': 'Human Computation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_computation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_computation'}, {'title': 'Crowdsourcing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing'}, {'title': 'Graph Theory', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Agraph_theory', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:graph_theory'}, {'title': 'Markov Chains', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amarkov_chains', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:markov_chains'}, {'title': 'Wireless Networks', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Awireless_networks', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:wireless_networks'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=crhkrNcAAAAJ&citpid=2'}
# {'coauthor_name': {'Alessandro Checco'}, 'coauthor_affiliations': 'Computer Science Department - University of Rome La Sapienza', 'coauthor_author_id': 'crhkrNcAAAAJ', 'coauthor_cited_by': 896, 'coauthor_interests': 'Wireless Networks'}
# {'name': 'Afshin Rahimi', 'link': 'https://scholar.google.com/citations?hl=en&user=WhPw2I0AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=WhPw2I0AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'WhPw2I0AAAAJ', 'affiliations': 'Applied Scientist @ Amazon', 'email': 'Verified email at uq.edu.au', 'cited_by': 1282, 'interests': [{'title': 'Natural Language Processing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Anatural_language_processing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:natural_language_processing'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=WhPw2I0AAAAJ&citpid=2'}
# {'coauthor_name': {'Afshin Rahimi'}, 'coauthor_affiliations': 'Applied Scientist @ Amazon', 'coauthor_author_id': 'WhPw2I0AAAAJ', 'coauthor_cited_by': 1282, 'coauthor_interests': 'Natural Language Processing'}
# {'name': 'Andrea Brunello', 'link': 'https://scholar.google.com/citations?hl=en&user=GuteS00AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=GuteS00AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'GuteS00AAAAJ', 'affiliations': 'Università degli Studi di Udine', 'email': 'Verified email at uniud.it', 'cited_by': 278, 'interests': [{'title': 'Data science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adata_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:data_science'}, {'title': 'machine learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amachine_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:machine_learning'}, {'title': 'evolutionary computation', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aevolutionary_computation', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:evolutionary_computation'}, {'title': 'data modelling', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adata_modelling', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:data_modelling'}, {'title': 'databases', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adatabases', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:databases'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=GuteS00AAAAJ&citpid=4'}
# {'coauthor_name': {'Andrea Brunello'}, 'coauthor_affiliations': 'Università degli Studi di Udine', 'coauthor_author_id': 'GuteS00AAAAJ', 'coauthor_cited_by': 278, 'coauthor_interests': 'databases'}
# {'name': 'Tetsuya Sakai', 'link': 'https://scholar.google.com/citations?hl=en&user=vi56gz4AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=vi56gz4AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'vi56gz4AAAAJ', 'affiliations': 'Waseda University', 'email': 'Verified email at waseda.jp', 'cited_by': 6613, 'interests': [{'title': 'information retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'natural language processing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Anatural_language_processing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:natural_language_processing'}, {'title': 'human computer interaction', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_computer_interaction', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_computer_interaction'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=vi56gz4AAAAJ&citpid=2'}
# {'coauthor_name': {'Tetsuya Sakai'}, 'coauthor_affiliations': 'Waseda University', 'coauthor_author_id': 'vi56gz4AAAAJ', 'coauthor_cited_by': 6613, 'coauthor_interests': 'human computer interaction'}
# {'name': 'Maddalena Zippi', 'link': 'https://scholar.google.com/citations?hl=en&user=j8YC3TAAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=j8YC3TAAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'j8YC3TAAAAAJ', 'affiliations': "Unita' di Gastroenterologia ed Endoscopia Digestiva, ospedale Sandro Pertini, Roma", 'email': 'Verified email at aslroma2.it', 'cited_by': 1739, 'interests': [{'title': 'endoscopia digestiva diagnostica e opertiva', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aendoscopia_digestiva_diagnostica_e_opertiva', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:endoscopia_digestiva_diagnostica_e_opertiva'}, {'title': 'endoscopia vie biliari', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aendoscopia_vie_biliari', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:endoscopia_vie_biliari'}, {'title': 'malattie infiammatorie croniche intestinali', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amalattie_infiammatorie_croniche_intestinali', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:malattie_infiammatorie_croniche_intestinali'}, {'title': 'malattie panc', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amalattie_panc', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:malattie_panc'}], 'thumbnail': 'https://scholar.google.com/citations/images/avatar_scholar_56.png'}
# {'coauthor_name': {'Eddy Maddalena'}, 'coauthor_affiliations': "Unita' di Gastroenterologia ed Endoscopia Digestiva, ospedale Sandro Pertini, Roma", 'coauthor_author_id': 'j8YC3TAAAAAJ', 'coauthor_cited_by': 1739, 'coauthor_interests': 'malattie panc'}
# {'name': 'Stefano Mizzaro', 'link': 'https://scholar.google.com/citations?hl=en&user=2wvJC6IAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=2wvJC6IAAAAJ&engine=google_scholar_author&hl=en', 'author_id': '2wvJC6IAAAAJ', 'affiliations': 'Full professor of Computer Science and Information Technology', 'email': 'Verified email at uniud.it', 'cited_by': 4732, 'interests': [{'title': 'Information retrieval', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_retrieval', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_retrieval'}, {'title': 'mobile systems', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amobile_systems', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:mobile_systems'}, {'title': 'scholarly publishing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ascholarly_publishing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:scholarly_publishing'}, {'title': 'crowdsourcing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acrowdsourcing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:crowdsourcing'}, {'title': 'misinformation and fake news detection', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amisinformation_and_fake_news_detection', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:misinformation_and_fake_news_detection'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=2wvJC6IAAAAJ&citpid=1'}
# {'coauthor_name': {'Stefano Mizzaro'}, 'coauthor_affiliations': 'Full professor of Computer Science and Information Technology', 'coauthor_author_id': '2wvJC6IAAAAJ', 'coauthor_cited_by': 4732, 'coauthor_interests': 'misinformation and fake news detection'}
# ...
# {'name': 'Luis-Daniel Ibáñez', 'link': 'https://scholar.google.com/citations?hl=en&user=Vf-AkkUAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=Vf-AkkUAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'Vf-AkkUAAAAJ', 'affiliations': 'University of Southampton', 'email': 'Verified email at soton.ac.uk', 'cited_by': 688, 'interests': [{'title': 'Linked Data', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Alinked_data', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:linked_data'}, {'title': 'Collaborative Systems', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acollaborative_systems', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:collaborative_systems'}, {'title': 'Optimistic Replication', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aoptimistic_replication', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:optimistic_replication'}, {'title': 'Provenance Semirings', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprovenance_semirings', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:provenance_semirings'}, {'title': 'Update Exchange', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aupdate_exchange', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:update_exchange'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=Vf-AkkUAAAAJ&citpid=3'}
# {'coauthor_name': {'Luis-Daniel Ibáñez'}, 'coauthor_affiliations': 'University of Southampton', 'coauthor_author_id': 'Vf-AkkUAAAAJ', 'coauthor_cited_by': 688, 'coauthor_interests': 'Update Exchange'}
# {'name': 'Vincenzo Della Mea', 'link': 'https://scholar.google.com/citations?hl=en&user=BF3B4KAAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=BF3B4KAAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'BF3B4KAAAAAJ', 'affiliations': 'Associate Professor of Medical Informatics, University of Udine', 'email': 'Verified email at uniud.it', 'cited_by': 2878, 'interests': [{'title': 'medical informatics', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amedical_informatics', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:medical_informatics'}, {'title': 'telemedicine', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Atelemedicine', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:telemedicine'}, {'title': 'digital pathology', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adigital_pathology', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:digital_pathology'}, {'title': 'biomedical classifications and ontologies', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Abiomedical_classifications_and_ontologies', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:biomedical_classifications_and_ontologies'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=BF3B4KAAAAAJ&citpid=7'}
# {'coauthor_name': {'Vincenzo Della Mea'}, 'coauthor_affiliations': 'Associate Professor of Medical Informatics, University of Udine', 'coauthor_author_id': 'BF3B4KAAAAAJ', 'coauthor_cited_by': 2878, 'coauthor_interests': 'biomedical classifications and ontologies'}
# {'name': 'Marco Basaldella', 'link': 'https://scholar.google.com/citations?hl=en&user=SRvx2QoAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=SRvx2QoAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'SRvx2QoAAAAJ', 'affiliations': 'Amazon', 'email': 'Verified email at amazon.co.uk', 'cited_by': 517, 'thumbnail': 'https://scholar.google.com/citations/images/avatar_scholar_56.png'}
# {'coauthor_name': {'Marco Basaldella'}, 'coauthor_affiliations': 'Amazon', 'coauthor_author_id': 'SRvx2QoAAAAJ', 'coauthor_cited_by': 517, 'coauthor_interests': ''}
# {'name': 'Mattia Zeni', 'link': 'https://scholar.google.com/citations?hl=en&user=DL18RZEAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=DL18RZEAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'DL18RZEAAAAJ', 'affiliations': 'Databricks, TomTom, IBM Research, University of Trento, Create-net', 'email': 'Verified email at databricks.com', 'cited_by': 608, 'interests': [{'title': 'Big Data', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Abig_data', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:big_data'}, {'title': 'AI', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aai', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:ai'}, {'title': 'Machine Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amachine_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:machine_learning'}, {'title': 'Human-Centered AI', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ahuman_centered_ai', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:human_centered_ai'}, {'title': 'Privacy-Aware Machine Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprivacy_aware_machine_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:privacy_aware_machine_learning'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=DL18RZEAAAAJ&citpid=3'}
# {'coauthor_name': {'Mattia Zeni'}, 'coauthor_affiliations': 'Databricks, TomTom, IBM Research, University of Trento, Create-net', 'coauthor_author_id': 'DL18RZEAAAAJ', 'coauthor_cited_by': 608, 'coauthor_interests': 'Privacy-Aware Machine Learning'}
# {'name': "Dante Degl'Innocenti", 'link': 'https://scholar.google.com/citations?hl=en&user=Ay6L7NsAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=Ay6L7NsAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'Ay6L7NsAAAAJ', 'affiliations': 'Datamantix', 'email': 'Verified email at spes.uniud.it', 'cited_by': 117, 'interests': [{'title': 'Artificial Intelligence', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aartificial_intelligence', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:artificial_intelligence'}, {'title': 'Deep Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adeep_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:deep_learning'}, {'title': 'Natural Language Processing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Anatural_language_processing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:natural_language_processing'}, {'title': 'Data Science', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adata_science', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:data_science'}, {'title': 'Machine Learning', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amachine_learning', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:machine_learning'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=Ay6L7NsAAAAJ&citpid=2'}
# {'coauthor_name': {"Dante Degl'Innocenti"}, 'coauthor_affiliations': 'Datamantix', 'coauthor_author_id': 'Ay6L7NsAAAAJ', 'coauthor_cited_by': 117, 'coauthor_interests': 'Machine Learning'}
# {'name': 'Pavlos Vougiouklis', 'link': 'https://scholar.google.com/citations?hl=en&user=9J7YeR0AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=9J7YeR0AAAAJ&engine=google_scholar_author&hl=en', 'author_id': '9J7YeR0AAAAJ', 'affiliations': 'Huawei Technologies', 'email': 'Verified email at huawei.com', 'cited_by': 574, 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=9J7YeR0AAAAJ&citpid=4'}
# {'coauthor_name': {'Pavlos Vougiouklis'}, 'coauthor_affiliations': 'Huawei Technologies', 'coauthor_author_id': '9J7YeR0AAAAJ', 'coauthor_cited_by': 574, 'coauthor_interests': ''}
# {'name': 'Jon Hare', 'link': 'https://scholar.google.com/citations?hl=en&user=d_HvmVsAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=d_HvmVsAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'd_HvmVsAAAAJ', 'affiliations': 'NOAA Fisheries, Northeast Fisheries Science Center', 'email': 'Verified email at noaa.gov', 'cited_by': 12271, 'interests': [{'title': 'oceanography', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aoceanography', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:oceanography'}, {'title': 'fisheries', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Afisheries', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:fisheries'}, {'title': 'climate change', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aclimate_change', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:climate_change'}, {'title': 'management', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Amanagement', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:management'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=d_HvmVsAAAAJ&citpid=3'}
# {'coauthor_name': {'Jonathon Hare'}, 'coauthor_affiliations': 'NOAA Fisheries, Northeast Fisheries Science Center', 'coauthor_author_id': 'd_HvmVsAAAAJ', 'coauthor_cited_by': 12271, 'coauthor_interests': 'management'}
# {'name': 'Carlo Alberto Beltrami', 'link': 'https://scholar.google.com/citations?hl=en&user=EZrMWWMAAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=EZrMWWMAAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'EZrMWWMAAAAJ', 'affiliations': 'Professore, Università di Udine', 'email': 'Verified email at uniud.it', 'cited_by': 18378, 'interests': [{'title': 'cellule staminali', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acellule_staminali', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:cellule_staminali'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=EZrMWWMAAAAJ&citpid=1'}
# {'coauthor_name': {'Carlo Alberto Beltrami'}, 'coauthor_affiliations': 'Professore, Università di Udine', 'coauthor_author_id': 'EZrMWWMAAAAJ', 'coauthor_cited_by': 18378, 'coauthor_interests': 'cellule staminali'}
# {'name': 'Richard Gomer', 'link': 'https://scholar.google.com/citations?hl=en&user=z1YBrC4AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=z1YBrC4AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'z1YBrC4AAAAJ', 'affiliations': 'Professor of Biology, Texas A&M University', 'email': 'Verified email at tamu.edu', 'cited_by': 10311, 'interests': [{'title': 'fibrosis', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Afibrosis', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:fibrosis'}, {'title': 'Dictyostelium', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Adictyostelium', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:dictyostelium'}, {'title': 'cell density sensing', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Acell_density_sensing', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:cell_density_sensing'}], 'thumbnail': 'https://scholar.googleusercontent.com/citations?view_op=small_photo&user=z1YBrC4AAAAJ&citpid=1'}
# {'coauthor_name': {'Richard Gomer'}, 'coauthor_affiliations': 'Professor of Biology, Texas A&M University', 'coauthor_author_id': 'z1YBrC4AAAAJ', 'coauthor_cited_by': 10311, 'coauthor_interests': 'cell density sensing'}
# {'name': 'Davide Ceolin', 'link': 'https://scholar.google.com/citations?hl=en&user=y8Jy518AAAAJ', 'serpapi_link': 'https://serpapi.com/search.json?author_id=y8Jy518AAAAJ&engine=google_scholar_author&hl=en', 'author_id': 'y8Jy518AAAAJ', 'affiliations': 'Tenured Researcher, CWI Amsterdam', 'email': 'Verified email at cwi.nl', 'cited_by': 493, 'interests': [{'title': 'Information Quality', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Ainformation_quality', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:information_quality'}, {'title': 'Trust', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Atrust', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:trust'}, {'title': 'Semantic Web', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Asemantic_web', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:semantic_web'}, {'title': 'Probabilistic Logic', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprobabilistic_logic', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:probabilistic_logic'}, {'title': 'Provenance', 'serpapi_link': 'https://serpapi.com/search.json?engine=google_scholar_profiles&hl=en&mauthors=label%3Aprovenance', 'link': 'https://scholar.google.com/citations?hl=en&view_op=search_authors&mauthors=label:provenance'}], 'thumbnail': 'https://scholar.google.com/citations/images/avatar_scholar_56.png'}
# {'coauthor_name': {'Davide Ceolin'}, 'coauthor_affiliations': 'Tenured Researcher, CWI Amsterdam', 'coauthor_author_id': 'y8Jy518AAAAJ', 'coauthor_cited_by': 493, 'coauthor_interests': 'Provenance'}
#      name  affiliations  author_id  cited_by  interests
# 0     NaN           NaN        NaN       NaN        NaN
# 1     NaN           NaN        NaN       NaN        NaN
# 2     NaN           NaN        NaN       NaN        NaN
# 3     NaN           NaN        NaN       NaN        NaN
# 4     NaN           NaN        NaN       NaN        NaN
# ..    ...           ...        ...       ...        ...
# 122   NaN           NaN        NaN       NaN        NaN
# 123   NaN           NaN        NaN       NaN        NaN
# 124   NaN           NaN        NaN       NaN        NaN
# 125   NaN           NaN        NaN       NaN        NaN
# 126   NaN           NaN        NaN       NaN        NaN
#
# [127 rows x 5 columns]

# %%
display(df_coauthor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 display(df_coauthor)
#
# NameError: name 'df_coauthor' is not defined
